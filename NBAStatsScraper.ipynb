# %%
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams

# %%
nba_teams = teams.get_teams()
nba_teams_id = []

for team in nba_teams:
    nba_teams_id.append(team['id'])

# %%
gamefinder = leaguegamefinder.LeagueGameFinder()
all_games = gamefinder.get_data_frames()[0]

# %%
nba_games = all_games[all_games['TEAM_ID'].isin(nba_teams_id)]

# %%
this_season = nba_games[nba_games.SEASON_ID.str[-4:] == '2023']
this_season['GAME_DATE'] = pd.to_datetime(this_season['GAME_DATE'])
this_season_beforeJan = this_season[this_season.GAME_DATE < pd.Timestamp(2024,1,1)]
# Out:
# /var/folders/5c/f6nf37n93j558dp3yz6khbth0000gn/T/ipykernel_1355/659183310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_season['GAME_DATE'] = pd.to_datetime(this_season['GAME_DATE'])

# %%
this_season_beforeJan
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 1219     22023  1610612747               LAL     Los Angeles Lakers
# 1220     22023  1610612751               BKN          Brooklyn Nets
# 1221     22023  1610612763               MEM      Memphis Grizzlies
# 1222     22023  1610612758               SAC       Sacramento Kings
# 1224     22023  1610612737               ATL          Atlanta Hawks
# ...        ...         ...               ...                    ...
# 3560     22023  1610612748               MIA             Miami Heat
# 3561     22023  1610612758               SAC       Sacramento Kings
# 3562     22023  1610612766               CHA      Charlotte Hornets
# 3563     22023  1610612744               GSW  Golden State Warriors
# 3564     22023  1610612747               LAL     Los Angeles Lakers
#
#          GAME_ID  GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 1219  0022300446 2023-12-31    LAL @ NOP  L  240  109  ...   0.840     4
# 1220  0022300447 2023-12-31    BKN @ OKC  L  241  108  ...   0.645    17
# 1221  0022300449 2023-12-31  MEM vs. SAC  L  241   92  ...   0.714     1
# 1222  0022300449 2023-12-31    SAC @ MEM  W  239  123  ...   0.765     9
# 1224  0022300445 2023-12-31    ATL @ WAS  W  240  130  ...   0.649    12
# ...          ...        ...          ... ..  ...  ...  ...     ...   ...
# 3560  1322300001 2023-07-03    MIA @ LAL  W  200  107  ...   0.727     9
# 3561  1322300003 2023-07-03  SAC vs. GSW  W  200  100  ...   0.767     9
# 3562  1322300002 2023-07-03  CHA vs. SAS  L  200   77  ...   0.630     6
# 3563  1322300003 2023-07-03    GSW @ SAC  L  201   94  ...   0.824     7
# 3564  1322300001 2023-07-03  LAL vs. MIA  L  200   90  ...   0.679    13
#
#       DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 1219    31   35   26    8   10   13  15       -20.0
# 1220    30   47   26    9    2    6  21       -16.0
# 1221    33   34   20    4    1    8  14       -31.0
# 1222    50   59   28    2    4   12  22        31.0
# 1224    46   58   27    5    3   12  18         4.0
# ...    ...  ...  ...  ...  ...  ...  ..         ...
# 3560    31   40   24    8    3   15  25        15.6
# 3561    23   32   11   10    4   13  27        10.8
# 3562    22   28   12    7    6   17  26       -20.4
# 3563    23   30   23    3    2   17  26        -9.2
# 3564    28   41   16    8    3   17  22       -16.2
#
# [1278 rows x 28 columns]

# %%
this_season_beforeJan.to_csv("2023_Game_Stats.csv", index=False)
